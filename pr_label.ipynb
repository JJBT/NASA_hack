# %%
import pandas as pd
import json
import os

from Constants import *

# %%
df = pd.read_csv(PATH_TO_ACC_DATA, sep=',')
# Out:
# c:\soft\python36\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[df["DATE"].apply(lambda x: ((int(x[6:])) >= 2015) and ((int(x[6:])) < 2018))]

# %%
df.columns
# Out:
# Index(['DATE', 'TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE',
#        'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME',
#        'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
#        'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
#        'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
#        'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
#        'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
#        'CONTRIBUTING FACTOR VEHICLE 5', 'UNIQUE KEY', 'VEHICLE TYPE CODE 1',
#        'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4',
#        'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df
# Out:
#               DATE   TIME        BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 106660  12/31/2017   2:29            NaN      NaN        NaN        NaN
# 106856  12/15/2017  16:45            NaN      NaN  40.705246 -73.959080
# 107027  12/13/2017   9:36            NaN      NaN  40.775986 -73.784610
# 107516  12/07/2017  18:40            NaN      NaN        NaN        NaN
# 180405  12/31/2017   0:00            NaN      NaN  40.884014 -73.879100
# 180427  12/31/2017   0:00          BRONX    10471  40.910130 -73.903220
# 180428  12/31/2017   0:00      MANHATTAN    10032  40.841730 -73.944340
# 180429  12/31/2017   0:00         QUEENS    11432  40.710133 -73.783330
# 180430  12/31/2017   0:00            NaN      NaN  40.602673 -73.899330
# 180431  12/31/2017   0:00            NaN      NaN  40.843600 -73.945110
# 180432  12/31/2017   0:01          BRONX    10456  40.828390 -73.916916
# 180433  12/31/2017   0:04       BROOKLYN    11231  40.674200 -73.999840
# ...

# %%
dfd = df["DATE"].value_counts()

# %%
dfd['02/29/2016']
# Out:
# 616

# %%
dfd.to_csv("Accident.csv")

# %%
len(dfd)
# Out:
# 1096
