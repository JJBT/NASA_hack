# %%
import pandas as pd
from Constants import *
from sklearn.ensemble import

# %%
data = pd.read_csv(PATH_TO_W_DATA)
data.head(5)
# Out:
# c:\soft\python36\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (10,11,14,15,20,23,25,67,84,85,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       STATION                STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 1  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 2  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 3  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 4  WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
#
#                DATE REPORTTPYE HOURLYSKYCONDITIONS HOURLYVISIBILITY  \
# 0  2015-01-01 00:51      FM-15              CLR:00            10.00
# 1  2015-01-01 01:51      FM-15              CLR:00            10.00
# ...

# %%
columns = [column for column in data.columns if 
           column.lower()[: 7] != 'monthly' and column.lower()[: 6] != 'hourly']
data = data[columns]
date_time = data['DATE']
data.drop(['DATE'], axis=1, inplace=True)

data['DATE'] = date_time.apply(lambda value: value.split(' ')[0])
data['TIME'] = date_time.apply(lambda value: value.split(' ')[1])

# %%
data
# Out:
#           STATION                STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 1      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 2      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 3      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 4      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 5      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 6      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 7      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 8      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 9      WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# 10     WBAN:94728  NY CITY CENTRAL PARK NY US       42.7  40.77898  -73.96925
# ...

# %%
data.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'ELEVATION', 'LATITUDE', 'LONGITUDE',
#        'REPORTTPYE', 'DAILYMaximumDryBulbTemp', 'DAILYMinimumDryBulbTemp',
#        'DAILYAverageDryBulbTemp', 'DAILYDeptFromNormalAverageTemp',
#        'DAILYAverageRelativeHumidity', 'DAILYAverageDewPointTemp',
#        'DAILYAverageWetBulbTemp', 'DAILYHeatingDegreeDays',
#        'DAILYCoolingDegreeDays', 'DAILYSunrise', 'DAILYSunset', 'DAILYWeather',
#        'DAILYPrecip', 'DAILYSnowfall', 'DAILYSnowDepth',
#        'DAILYAverageStationPressure', 'DAILYAverageSeaLevelPressure',
#        'DAILYAverageWindSpeed', 'DAILYPeakWindSpeed', 'PeakWindDirection',
#        'DAILYSustainedWindSpeed', 'DAILYSustainedWindDirection', 'DATE',
#        'TIME'],
#       dtype='object')

# %%
new_data = data.drop(['STATION', 'STATION_NAME', 'ELEVATION', 'LATITUDE', 'LONGITUDE', 'REPORTTPYE', 'DAILYDeptFromNormalAverageTemp', 'DAILYAverageWetBulbTemp', 'DAILYHeatingDegreeDays',
       'DAILYCoolingDegreeDays', 'DAILYSunrise', 'DAILYSunset', 'DAILYPeakWindSpeed', 'PeakWindDirection', 'DAILYSustainedWindSpeed', 'DAILYSustainedWindDirection'], axis=1)
new_data.shape
# Out:
# (34019, 14)

# %%
new_data.columns
# Out:
# Index(['DAILYMaximumDryBulbTemp', 'DAILYMinimumDryBulbTemp',
#        'DAILYAverageDryBulbTemp', 'DAILYAverageRelativeHumidity',
#        'DAILYAverageDewPointTemp', 'DAILYWeather', 'DAILYPrecip',
#        'DAILYSnowfall', 'DAILYSnowDepth', 'DAILYAverageStationPressure',
#        'DAILYAverageSeaLevelPressure', 'DAILYAverageWindSpeed', 'DATE',
#        'TIME'],
#       dtype='object')

# %%
unique_dates = new_data["DATE"].unique()

# %%
new_data["DATE"].value_counts().head(5)
# Out:
# 2016-02-24    79
# 2017-07-23    78
# 2017-10-29    70
# 2015-12-23    68
# 2015-06-15    68
# Name: DATE, dtype: int64

# %%
new_data
# Out:
#        DAILYMaximumDryBulbTemp  DAILYMinimumDryBulbTemp  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                         NaN                      NaN
# 13                         NaN                      NaN
# 14                         NaN                      NaN
# 15                         NaN                      NaN
# ...

# %%
new_data["NEW_F"] = new_data[new_data["DATE"] == '2015-01-01']["DAILYMaximumDryBulbTemp"].fillna(new_data[new_data["DATE"] == '2015-01-01']["DAILYMaximumDryBulbTemp"][pd.notnull(new_data[new_data["DATE"] == '2015-01-01']
                                                                                 ["DAILYMaximumDryBulbTemp"])].mean())

# %%
new_data[new_data["DATE"] == '2015-01-02'].loc[:, "NEW_F"].fillna(0, inplace=True, co)
# Out:
# c:\soft\python36\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
new_data
# Out:
#        DAILYMaximumDryBulbTemp  DAILYMinimumDryBulbTemp  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# 5                          NaN                      NaN
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                          NaN                      NaN
# 10                         NaN                      NaN
# 11                         NaN                      NaN
# 12                         NaN                      NaN
# 13                         NaN                      NaN
# 14                         NaN                      NaN
# 15                         NaN                      NaN
# ...

# %%
new_data[new_data.loc[:, "DATE"] == '2015-01-01'].loc[:, "DAILYMaximumDryBulbTemp"] = col1
# Out:
# c:\soft\python36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
new_data[new_data["DATE"] == '2015-01-01']
# Out:
#     DAILYMaximumDryBulbTemp  DAILYMinimumDryBulbTemp  DAILYAverageDryBulbTemp  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                       NaN                      NaN                      NaN
# 4                       NaN                      NaN                      NaN
# 5                       NaN                      NaN                      NaN
# 6                       NaN                      NaN                      NaN
# 7                       NaN                      NaN                      NaN
# 8                       NaN                      NaN                      NaN
# 9                       NaN                      NaN                      NaN
# 10                      NaN                      NaN                      NaN
# ...

# %%
new_data[new_data["DATE"] == date] = new_data[new_data["DATE"] == date]["DAILYMaximumDryBulbTemp"].fillna(new_data[new_data["DATE"] == date]["DAILYMaximumDryBulbTemp"]\
                                           [pd.notnull(new_data[new_data["DATE"] == date]["DAILYMaximumDryBulbTemp"])].mean())

# %%
for date in unique_dates:
    new_data[new_data["DATE"] == date]["DAILYMaximumDryBulbTemp"] = new_data[new_data["DATE"] == date]["DAILYMaximumDryBulbTemp"].fillna(new_data[new_data["DATE"] == date]["DAILYMaximumDryBulbTemp"]\
                                           [pd.notnull(new_data[new_data["DATE"] == date]["DAILYMaximumDryBulbTemp"])].mean())
# Out:
# c:\soft\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_data[new_data["DATE"] == '2015-01-01']
# Out:
#     DAILYMaximumDryBulbTemp  DAILYMinimumDryBulbTemp  DAILYAverageDryBulbTemp  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                       NaN                      NaN                      NaN
# 3                       NaN                      NaN                      NaN
# 4                       NaN                      NaN                      NaN
# 5                       NaN                      NaN                      NaN
# 6                       NaN                      NaN                      NaN
# 7                       NaN                      NaN                      NaN
# 8                       NaN                      NaN                      NaN
# 9                       NaN                      NaN                      NaN
# 10                      NaN                      NaN                      NaN
# ...

# %%
newest_data = new_data[new_data['TIME'] == '23:59']
newest_data.reset_index(inplace=True)
print(newest_data)
newest_data.drop('index', axis=1, inplace=True)
print(newest_data)
# Out:
#       index  DAILYMaximumDryBulbTemp  DAILYMinimumDryBulbTemp  \
# 0        24                     39.0                     27.0
# 1        49                     42.0                     35.0
# 2       109                     42.0                     33.0
# 3       161                     56.0                     41.0
# 4       186                     49.0                     21.0
# 5       228                     22.0                     19.0
# 6       253                     23.0                      9.0
# 7       278                     21.0                      8.0
# 8       314                     33.0                     19.0
# 9       339                     23.0                     16.0
# 10      364                     37.0                     18.0
# 11      417                     39.0                     35.0
# 12      447                     36.0                     17.0
# 13      486                     32.0                     16.0
# ...

# %%
newest_data['DAILYPrecip'].value_counts()
# Out:
# 0.00    679
# T        70
# 0.01     37
# 0.02     22
# 0.06     14
# 0.04     13
# 0.05     13
# 0.03     13
# 0.09     11
# 0.29      8
# 0.11      7
# 0.12      6
# 0.30      6
# 0.08      5
# 0.10      5
# 0.32      5
# 0.20      5
# 0.25      5
# 0.07      5
# 0.45      5
# 0.22      5
# 0.16      4
# 0.36      4
# 0.23      4
# 0.35      4
# 0.14      4
# 0.19      4
# 0.73      4
# 0.13      3
# 0.27      3
#        ...
# 2.31      1
# 0.59      1
# 1.46      1
# 0.66      1
# 3.02      1
# 0.71      1
# 1.51      1
# 1.41      1
# 0.68      1
# 1.35      1
# 1.26      1
# 1.29      1
# 1.17      1
# 1.81      1
# 1.40      1
# 1.09      1
# 1.37      1
# 1.95      1
# 3.03      1
# 2.10      1
# 0.67      1
# 1.80      1
# 2.20      1
# 1.39      1
# 1.25      1
# 1.11      1
# 1.22      1
# 1.78      1
# 0.82      1
# 1.61      1
# Name: DAILYPrecip, Length: 113, dtype: int64
